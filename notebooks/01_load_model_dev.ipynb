# %% [markdown]
# # 🦙 01 — Cargar TinyLlama en DEV
# Carga el modelo base sin fine-tuning y probarlo con Gradio.
#
# > **Runtime recomendado:** CPU o T4 GPU (gratis en Colab)

# %% [markdown]
# ## 1. Clonar el repo

# %%
# !git clone -b dev https://github.com/Dvilchess/lillama
# Out:
# Cloning into 'lillama'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 57 (delta 13), reused 57 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (57/57), 497.17 KiB | 9.94 MiB/s, done.
# Resolving deltas: 100% (13/13), done.

# %%
# !git pull origin dev
# Out:
# From https://github.com/Dvilchess/lillama
#  * branch            dev        -> FETCH_HEAD
# Already up to date.

# %%
# !git fetch origin
# !git reset --hard origin/dev
# !git pull
# Out:
# HEAD is now at 210e8b8 act
# Already up to date.

# %%
import os

GITHUB_USER = "Dvilchess"  # <-- cambiá esto
REPO = "lillama"
BRANCH = "dev"

if not os.path.exists(REPO):
    # !git clone -b {BRANCH} https://github.com/{GITHUB_USER}/{REPO}
else:
    # !cd {REPO} && git pull

# %cd {REPO}
print('Repo listo')
# Out:
# Cloning into 'lillama'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 57 (delta 13), reused 57 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (57/57), 497.17 KiB | 15.07 MiB/s, done.
# Resolving deltas: 100% (13/13), done.
# /content/lillama/lillama/lillama/lillama/lillama
# Repo listo

# %% [markdown]
# ## 2. Instalar dependencias

# %%
# !pip install -q -r requirements.txt
print('Dependencias instaladas')
# Out:
# Dependencias instaladas

# %% [markdown]
# ## 3. Verificar GPU

# %%
import torch
print(f'CUDA disponible: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')
    print(f'VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB')
else:
    print('Corriendo en CPU — más lento pero funciona')
# Out:
# CUDA disponible: True
# GPU: Tesla T4
# VRAM: 15.6 GB

# %% [markdown]
# ## 4. Cargar el modelo

# %%
import os
os.environ["MAX_NEW_TOKENS"] = "128"
import sys
sys.path.insert(0, '.')
os.environ['ENV'] = 'dev'

from app.model import llm
llm.load()
print('Modelo cargado!')
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/transformers/utils/hub.py in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     418             # This is slightly better for only 1 file
# --> 419             hf_hub_download(
#     420                 path_or_repo_id,
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#      84             if arg_name in ["repo_id", "from_id", "to_id"]:
# ---> 85                 validate_repo_id(arg_value)
#      86
#
# ...

# %% [markdown]
# import os
# GITHUB_USER = "Dvilchess"
# REPO = "lillama"
# BRANCH = "dev"
#
# if not os.path.exists(REPO):
#     !git clone -b {BRANCH} https://github.com/{GITHUB_USER}/{REPO}
# else:
#     !cd {REPO} && git pull
#
# %cd {REPO}
# print('Repo listo')

# %%
# !cat lillama/app/config.py
# Out:
# cat: lillama/app/config.py: No such file or directory

# %% [markdown]
# ## 5. Prueba rápida

# %%
respuesta = llm.generate(
    prompt="¿quien eres tu?",
    system_prompt="Eres un asistente grosero"
)
print(respuesta)
# Out:
# Both `max_new_tokens` (=512) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)

# %% [markdown]
# ## 6. Levantar Gradio (UI pública temporal)

# %%
os.environ['GRADIO_SHARE'] = 'true'  # genera link público temporal

from app.main import build_ui
demo = build_ui()
demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://1a897707b37c057382.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://1a897707b37c057382.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
